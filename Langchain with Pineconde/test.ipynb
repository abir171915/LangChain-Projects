# %% [markdown]
# #### Importing Libraries

# %%
import openai
import langchain
import pinecone
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeSparseVectorStore
from langchain_openai import ChatOpenAI
import os

# %% [markdown]
# #### Loading environment variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Reading the pdf document

# %%
def read_doc(directory):
    file_loader = PyPDFDirectoryLoader(directory)
    documents = file_loader.load()
    return documents

# %%
doc = read_doc('document/')

# %%
len(doc)
# Out:
# 3

# %% [markdown]
# ### Converting the documents into chunks for the model restriction of token size

# %%
def chunk_data(doc, chunk_size = 500, chunk_overlap = 50):
    text_spliter = RecursiveCharacterTextSplitter(chunk_size = chunk_size, chunk_overlap = chunk_overlap)
    doc = text_spliter.split_documents(doc)
    return doc

# %%
documents = chunk_data(doc = doc)
documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m132', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36', 'creationdate': '2025-02-05T22:06:35+00:00', 'title': 'View your immigration status – GOV.UK', 'moddate': '2025-02-05T22:06:35+00:00', 'source': 'document\\View your immigration status – GOV.UK.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Name HOSSAIN MD\nABIR\nDate of\nbirth\n4 November 1997\nNational\nity\nBGD\nStatus Graduate Route\nValid\nfrom\n19 December\n2024\nValid\nuntil\n19 December\n2026\nIf any of the information\ndisplayed on your status\nis incorrect, contact UK\nVisas and Immigration\n(https://www.gov.uk/contact-\nukvi-inside-outside-uk).\nProve your status\nIf you need to prove your\nimmigration status to\nsomeone, you can do this\nonline with a share code.\nYour immigration\nstatus\nView and prove your immigration status'),
#  Document(metadata={'producer': 'Skia/PDF m132', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36', 'creationdate': '2025-02-05T22:06:35+00:00', 'title': 'View your immigration status – GOV.UK', 'moddate': '2025-02-05T22:06:35+00:00', 'source': 'document\\View your immigration status – GOV.UK.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='status\nView and prove your immigration status\n05/02/2025, 22:06 View your immigration status – GOV.UK\nhttps://view-immigration-status.service.gov.uk/status 1/3'),
#  Document(metadata={'producer': 'Skia/PDF m132', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36', 'creationdate': '2025-02-05T22:06:35+00:00', 'title': 'View your immigration status – GOV.UK', 'moddate': '2025-02-05T22:06:35+00:00', 'source': 'document\\View your immigration status – GOV.UK.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='What you can do in the UK\nYou can:\nlive in the UK\nstudy\nrent somewhere to live in the UK\nuse the National Health Service (NHS) in a\nsimilar way to permanent UK residents\naccess a current account with a bank or building\nsociety in the UK\ntravel in and out of the country if you can\nprovide a valid passport or travel document -\nyou may not be able to enter the UK without\none\nThings you cannot do\nYou cannot:\naccess public funds\nwork as a professional sportsperson or sports\ncoach'),
#  Document(metadata={'producer': 'Skia/PDF m132', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36', 'creationdate': '2025-02-05T22:06:35+00:00', 'title': 'View your immigration status – GOV.UK', 'moddate': '2025-02-05T22:06:35+00:00', 'source': 'document\\View your immigration status – GOV.UK.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='coach\nundertake further study with a student sponsor\non a course which would meet the requirements\nof the student route\nstudy at an academy or state school\nContinuous Absence\nIf you remain outside the UK for a continuous\nperiod of more than 2 years, your permission will\nnormally lapse if it has not yet expired and you will\nhave to apply for a new visa.\nLegal basis of status\nYou have been granted permission to stay in the\nUK (also known as leave to remain) until 19\nDecember 2026.'),
#  Document(metadata={'producer': 'Skia/PDF m132', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36', 'creationdate': '2025-02-05T22:06:35+00:00', 'title': 'View your immigration status – GOV.UK', 'moddate': '2025-02-05T22:06:35+00:00', 'source': 'document\\View your immigration status – GOV.UK.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='December 2026.\nGet a share code\n05/02/2025, 22:06 View your immigration status – GOV.UK\nhttps://view-immigration-status.service.gov.uk/status 2/3'),
#  Document(metadata={'producer': 'Skia/PDF m132', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36', 'creationdate': '2025-02-05T22:06:35+00:00', 'title': 'View your immigration status – GOV.UK', 'moddate': '2025-02-05T22:06:35+00:00', 'source': 'document\\View your immigration status – GOV.UK.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='National Insurance number\nYou will need to obtain a National Insurance\nnumber if you plan to work in the UK. If you have\none already, it will show at the top of your\nimmigration status profile. If you do not have a\nNational Insurance number, you must apply for\none. You can start work while you are waiting for a\nNational Insurance number if you can prove your\nright to work to your employer. If it has been more\nthan 8 weeks since you applied for a National'),
#  Document(metadata={'producer': 'Skia/PDF m132', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36', 'creationdate': '2025-02-05T22:06:35+00:00', 'title': 'View your immigration status – GOV.UK', 'moddate': '2025-02-05T22:06:35+00:00', 'source': 'document\\View your immigration status – GOV.UK.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='than 8 weeks since you applied for a National\nInsurance number, call the application helpline.\nIf your personal details change\nYou must tell us about any changes to your\npersonal details, such as your name or nationality.\nYou should also tell us if your sign-in or travel\ndocument details change, so that you can\ncontinue to access your information online.\nYou can use this service (https://update-your-\ndetails.homeoffice.gov.uk) to tell us about changes to\nyour\nemail address\nphone number'),
#  Document(metadata={'producer': 'Skia/PDF m132', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36', 'creationdate': '2025-02-05T22:06:35+00:00', 'title': 'View your immigration status – GOV.UK', 'moddate': '2025-02-05T22:06:35+00:00', 'source': 'document\\View your immigration status – GOV.UK.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='your\nemail address\nphone number\nhome address\npassport or travel document details, including\nchange of name or nationality\nFinish and leave service (/leave)\n05/02/2025, 22:06 View your immigration status – GOV.UK\nhttps://view-immigration-status.service.gov.uk/status 3/3')]

# %%
len(documents)
# Out:
# 8
